# %%
# !pip install setuptools==68.2.2
# !pip install torch
# !pip install sacremoses
# !pip install sentencepiece
# !pip install transformers
# Out:
# Requirement already satisfied: setuptools==68.2.2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (68.2.2)
# Requirement already satisfied: torch in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (2.2.0)
# Requirement already satisfied: filelock in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: sacremoses in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (0.1.1)
# Requirement already satisfied: regex in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses) (2023.12.25)
# Requirement already satisfied: click in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses) (4.66.2)
# Requirement already satisfied: colorama in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from click->sacremoses) (0.4.6)
# Requirement already satisfied: sentencepiece in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (0.1.99)
# Requirement already satisfied: transformers in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (4.37.2)
# Requirement already satisfied: filelock in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.30.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: colorama in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2023.5.7)

# %%
# !pip install git+https://github.com/VarunGumma/IndicTransTokenizer
# Out:
# Collecting git+https://github.com/VarunGumma/IndicTransTokenizer
#   Cloning https://github.com/VarunGumma/IndicTransTokenizer to c:\users\nitish\appdata\local\temp\pip-req-build-wo2w45f7
#   Resolved https://github.com/VarunGumma/IndicTransTokenizer to commit 5d4b278029393b220480b5d41a1c4093021b5471
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library (from IndicTransTokenizer==0.1.3)
#   Cloning https://github.com/VarunGumma/indic_nlp_library to c:\users\nitish\appdata\local\temp\pip-install-yh_wvwgv\indic-nlp-library-it2_d23dfd23275e49d1a8088994857bb5cb
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 1dd6683a6dd77be3c1dbe03c226201661235c72b
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools==68.2.2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from IndicTransTokenizer==0.1.3) (68.2.2)
# Requirement already satisfied: torch in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from IndicTransTokenizer==0.1.3) (2.2.0)
# Requirement already satisfied: sacremoses in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from IndicTransTokenizer==0.1.3) (0.1.1)
# Requirement already satisfied: sentencepiece in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from IndicTransTokenizer==0.1.3) (0.1.99)
# Requirement already satisfied: transformers in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from IndicTransTokenizer==0.1.3) (4.37.2)
# Collecting sacrebleu==2.3.1 (from IndicTransTokenizer==0.1.3)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#      ---------------------------------------- 57.0/57.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: portalocker in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (2.8.2)
# Requirement already satisfied: regex in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (1.23.5)
# Requirement already satisfied: colorama in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (0.4.6)
# Requirement already satisfied: lxml in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (5.2.1)
# Requirement already satisfied: sphinx-argparse in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (0.4.0)
# Requirement already satisfied: sphinx_rtd_theme in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.0.0)
# Requirement already satisfied: morfessor in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.0.6)
# Requirement already satisfied: pandas in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.0.1)
# Requirement already satisfied: click in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses->IndicTransTokenizer==0.1.3) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses->IndicTransTokenizer==0.1.3) (1.2.0)
# Requirement already satisfied: tqdm in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacremoses->IndicTransTokenizer==0.1.3) (4.66.2)
# Requirement already satisfied: filelock in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (4.9.0)
# Requirement already satisfied: sympy in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (1.12)
# Requirement already satisfied: networkx in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from torch->IndicTransTokenizer==0.1.3) (2024.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (6.0)
# Requirement already satisfied: requests in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (2.30.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from transformers->IndicTransTokenizer==0.1.3) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch->IndicTransTokenizer==0.1.3) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2023.3)
# Requirement already satisfied: pywin32>=226 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from portalocker->sacrebleu==2.3.1->IndicTransTokenizer==0.1.3) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers->IndicTransTokenizer==0.1.3) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers->IndicTransTokenizer==0.1.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers->IndicTransTokenizer==0.1.3) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers->IndicTransTokenizer==0.1.3) (2023.5.7)
# Requirement already satisfied: sphinx>=1.2.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (7.2.6)
# Requirement already satisfied: docutils<0.21 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx_rtd_theme->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (0.20.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx_rtd_theme->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (4.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch->IndicTransTokenizer==0.1.3) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.0.7)
# Requirement already satisfied: Pygments>=2.14 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.15.1)
# Requirement already satisfied: snowballstemmer>=2.0 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.2.0)
# Requirement already satisfied: babel>=2.9 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (2.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==0.1.3) (1.4.1)
# Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.9 kB ? eta -:--:--
#    ---------------------------------------- 118.9/118.9 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: sacrebleu
#   Attempting uninstall: sacrebleu
#     Found existing installation: sacrebleu 2.4.1
#     Uninstalling sacrebleu-2.4.1:
#       Successfully uninstalled sacrebleu-2.4.1
# Successfully installed sacrebleu-2.3.1
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/IndicTransTokenizer 'C:\Users\Nitish\AppData\Local\Temp\pip-req-build-wo2w45f7'
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library 'C:\Users\Nitish\AppData\Local\Temp\pip-install-yh_wvwgv\indic-nlp-library-it2_d23dfd23275e49d1a8088994857bb5cb'

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (2.3.1)
# Requirement already satisfied: portalocker in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (1.23.5)
# Requirement already satisfied: colorama in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from sacrebleu) (5.2.1)
# Requirement already satisfied: pywin32>=226 in c:\users\nitish\appdata\local\programs\python\python311\lib\site-packages (from portalocker->sacrebleu) (306)

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

tokenizer = IndicTransTokenizer(direction="en-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)

sentences = [
    "This is a test sentence.",
    "This is another longer different test sentence.",
    "Please send an SMS to 9876543210 and an email on newemail123@xyz.com by 15th October, 2023.",
]

batch = ip.preprocess_batch(sentences, src_lang="eng_Latn", tgt_lang="hin_Deva")
batch = tokenizer(batch, src=True, return_tensors="pt")

with torch.inference_mode():
    outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

outputs = tokenizer.batch_decode(outputs, src=False)
outputs = ip.postprocess_batch(outputs, lang="hin_Deva")
print(outputs)
# Out:
# ['यह एक परीक्षण वाक्य है।', 'यह एक और लंबा अलग परीक्षण वाक्य है।', 'कृपया 9876543210 पर एक एस. एम. एस. और 15 अक्टूबर, 2023 तक newemail123@xyz.com पर एक ईमेल भेजें।']

# %%
sentences = [
    "You are a good man",
]

batch = ip.preprocess_batch(sentences, src_lang="eng_Latn", tgt_lang="hin_Deva")
batch = tokenizer(batch, src=True, return_tensors="pt")

with torch.inference_mode():
    outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

outputs = tokenizer.batch_decode(outputs, src=False)
outputs = ip.postprocess_batch(outputs, lang="hin_Deva")
print(outputs)
# Out:
# ['आप एक अच्छे आदमी हैं।']
